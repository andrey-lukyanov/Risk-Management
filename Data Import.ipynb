# %%
#conda install pandas-datareader

import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader.data as web

# %%
start_date = '2016-1-1'
end_date = '2018-1-1'

# %%
GAZP = web.DataReader('GAZP', 'moex', start_date, end_date)

# %%
GAZP
# Out:
#            BOARDID   SHORTNAME SECID  NUMTRADES         VALUE    OPEN     LOW  \
# TRADEDATE
# 2016-01-04    SMAL  ГАЗПРОМ ао  GAZP         16  5.397930e+03  135.24  134.54
# 2016-01-04    EQDP  ГАЗПРОМ ао  GAZP          0  0.000000e+00     NaN     NaN
# 2016-01-05    SMAL  ГАЗПРОМ ао  GAZP         15  7.089800e+03  136.11  136.11
# 2016-01-05    EQDP  ГАЗПРОМ ао  GAZP          0  0.000000e+00     NaN     NaN
# 2016-01-05    TQBR  ГАЗПРОМ ао  GAZP      20646  1.942157e+09  134.66  134.61
# 2016-01-06    EQDP  ГАЗПРОМ ао  GAZP          0  0.000000e+00     NaN     NaN
# 2016-01-06    TQBR  ГАЗПРОМ ао  GAZP      12578  1.413184e+09  136.31  135.30
# 2016-01-06    SMAL  ГАЗПРОМ ао  GAZP          8  1.896900e+03  136.56  135.23
# 2016-01-11    SMAL  ГАЗПРОМ ао  GAZP         13  7.771600e+03  131.19  131.19
# 2016-01-11    EQDP  ГАЗПРОМ ао  GAZP          0  0.000000e+00     NaN     NaN
# 2016-01-11    TQBR  ГАЗПРОМ ао  GAZP      39721  4.489337e+09  133.00  131.10
# ...
